# %% [markdown]
# # Pyber Challenge
# V. Isualize has given you and Omar a brand-new assignment. Using your Python skills and knowledge of Pandas, you’ll create a summary DataFrame of the ride-sharing data by city type. Then, using Pandas and Matplotlib, you’ll create a multiple-line graph that shows the total weekly fares for each city type. Finally, you’ll submit a written report that summarizes how the data differs by city type and how those differences can be used by decision-makers at PyBer.

# %% [markdown]
# ### Deliverable 1: A ride-sharing summary DataFrame by city type

# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %%
#Review the source data sets : City Data (before merging)
city_data_df.head()
# Out:
#            city  driver_count   type
# 0   Richardfort            38  Urban
# 1  Williamsstad            59  Urban
# 2   Port Angela            67  Urban
# 3    Rodneyfort            34  Urban
# 4   West Robert            39  Urban

# %%
#Review the source data sets : Ride Data (before merging)
ride_data_df.head()
# Out:
#                  city                 date   fare        ride_id
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
rides = pyber_data_df.groupby(['type']).count()['ride_id']
rides
# Out:
# type
# Rural        125
# Suburban     625
# Urban       1625
# Name: ride_id, dtype: int64

# %%
# 2. Get the total drivers for each city type
drivers = city_data_df.groupby(['type']).sum()['driver_count']
drivers
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fares = pyber_data_df.groupby(['type']).sum()['fare']
fares
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type. 
mean_ride_fare = round((fares/rides),2)
mean_ride_fare
# Out:
# type
# Rural       34.62
# Suburban    30.97
# Urban       24.53
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
mean_drive_fare = round((fares/drivers),2)
mean_drive_fare
# Out:
# type
# Rural       55.49
# Suburban    39.50
# Urban       16.57
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
summary_df = pd.DataFrame({
    'Total Rides': rides,
    'Total Drivers' : drivers,
    'Total Fares' : fares,
    'Average Fare per Ride' : mean_ride_fare,
    'Average Fare per Driver' : mean_drive_fare})
summary_df
# Out:
#           Total Rides  Total Drivers  Total Fares  Average Fare per Ride  \
# type
# Rural             125             78      4327.93                  34.62
# Suburban          625            490     19356.33                  30.97
# Urban            1625           2405     39854.38                  24.53
#
#           Average Fare per Driver
# type
# Rural                       55.49
# Suburban                    39.50
# Urban                       16.57

# %%
#  7. Cleaning up the DataFrame. Delete the index name
summary_df.index.name = None

# %%
summary_format_df = summary_df.style.format({
    'Total Rides': '{:,d}',
    'Total Drivers': '{:,d}',
    'Total Fares': '${:20,.2f}',
    'Average Fare per Ride': '${:20,.2f}',
    'Average Fare per Driver':'${:20,.2f}'
    })

summary_format_df
# Out:
# <style type="text/css">
# </style>
# <table id="T_1591f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1591f_level0_col0" class="col_heading level0 col0" >Total Rides</th>
#       <th id="T_1591f_level0_col1" class="col_heading level0 col1" >Total Drivers</th>
#       <th id="T_1591f_level0_col2" class="col_heading level0 col2" >Total Fares</th>
#       <th id="T_1591f_level0_col3" class="col_heading level0 col3" >Average Fare per Ride</th>
#       <th id="T_1591f_level0_col4" class="col_heading level0 col4" >Average Fare per Driver</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1591f_level0_row0" class="row_heading level0 row0" >Rural</th>
#       <td id="T_1591f_row0_col0" class="data row0 col0" >125</td>
#       <td id="T_1591f_row0_col1" class="data row0 col1" >78</td>
#       <td id="T_1591f_row0_col2" class="data row0 col2" >$            4,327.93</td>
#       <td id="T_1591f_row0_col3" class="data row0 col3" >$               34.62</td>
#       <td id="T_1591f_row0_col4" class="data row0 col4" >$               55.49</td>
#     </tr>
#     <tr>
#       <th id="T_1591f_level0_row1" class="row_heading level0 row1" >Suburban</th>
#       <td id="T_1591f_row1_col0" class="data row1 col0" >625</td>
#       <td id="T_1591f_row1_col1" class="data row1 col1" >490</td>
#       <td id="T_1591f_row1_col2" class="data row1 col2" >$           19,356.33</td>
#       <td id="T_1591f_row1_col3" class="data row1 col3" >$               30.97</td>
#       <td id="T_1591f_row1_col4" class="data row1 col4" >$               39.50</td>
#     </tr>
#     <tr>
#       <th id="T_1591f_level0_row2" class="row_heading level0 row2" >Urban</th>
#       <td id="T_1591f_row2_col0" class="data row2 col0" >1,625</td>
#       <td id="T_1591f_row2_col1" class="data row2 col1" >2,405</td>
#       <td id="T_1591f_row2_col2" class="data row2 col2" >$           39,854.38</td>
#       <td id="T_1591f_row2_col3" class="data row2 col3" >$               24.53</td>
#       <td id="T_1591f_row2_col4" class="data row2 col4" >$               16.57</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df.head(15)
# Out:
#                    city                 date   fare        ride_id  \
# 0    Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1    South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2    Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3            Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4            South Jack  2019-03-06 04:28:35  34.58  3908451377344
# 5          South Latoya  2019-03-11 12:26:48   9.52  1994999424437
# 6         New Paulville  2019-02-27 11:17:56  43.25   793208410091
# 7          Simpsonburgh  2019-04-26 00:43:24  35.98   111953927754
# 8       South Karenland  2019-01-08 03:28:48  35.09  7995623208694
# 9         North Jasmine  2019-03-09 06:26:29  42.81  5327642267789
# 10  New Kimberlyborough  2019-02-07 01:10:11   9.34  7992781920789
# 11          West Angela  2019-01-12 01:45:27  26.86  4820052223501
# 12           Rodneyfort  2019-03-02 18:03:20  44.26  2494064867705
# 13          West Angela  2019-01-10 12:17:31  12.74  2108723916092
# 14          Roberthaven  2019-05-04 14:48:56  25.66  1026197778354
#
#     driver_count   type
# 0              5  Urban
# 1             72  Urban
# 2             57  Urban
# 3             34  Urban
# 4             46  Urban
# 5             10  Urban
# 6             44  Urban
# 7             21  Urban
# 8              4  Urban
# 9             33  Urban
# 10            33  Urban
# 11            48  Urban
# 12            34  Urban
# 13            48  Urban
# 14            47  Urban

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
new_pyber_df = pyber_data_df.groupby(['type','date']).sum()['fare']
new_pyber_df.head()
# Out:
# type   date
# Rural  2019-01-01 09:45:36    43.69
#        2019-01-02 11:18:32    52.12
#        2019-01-03 19:51:01    19.90
#        2019-01-04 03:31:26    24.88
#        2019-01-06 07:38:40    47.33
# Name: fare, dtype: float64

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
new_pyber_df = new_pyber_df.reset_index()
new_pyber_df
# Out:
#        type                 date   fare
# 0     Rural  2019-01-01 09:45:36  43.69
# 1     Rural  2019-01-02 11:18:32  52.12
# 2     Rural  2019-01-03 19:51:01  19.90
# 3     Rural  2019-01-04 03:31:26  24.88
# 4     Rural  2019-01-06 07:38:40  47.33
# ...     ...                  ...    ...
# 2370  Urban  2019-05-08 04:20:00  21.99
# 2371  Urban  2019-05-08 04:39:49  18.45
# 2372  Urban  2019-05-08 07:29:01  18.55
# 2373  Urban  2019-05-08 11:38:35  19.77
# 2374  Urban  2019-05-08 13:10:18  18.04
#
# [2375 rows x 3 columns]

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 
pivot_pyber_df = new_pyber_df.pivot(index='date', columns='type', values='fare')
pivot_pyber_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
loc_pivot_df = pivot_pyber_df.loc['2019-01-01':'2019-04-28']
loc_pivot_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-27 17:58:27  14.01       NaN    NaN
# 2019-04-27 19:45:48    NaN     28.84    NaN
# 2019-04-27 20:41:36    NaN       NaN   8.28
# 2019-04-27 23:26:03    NaN       NaN  19.06
# 2019-04-27 23:52:44    NaN     45.98    NaN
#
# [2177 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)
loc_pivot_df.index = pd.to_datetime(loc_pivot_df.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
loc_pivot_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2177 entries, 2019-01-01 00:08:16 to 2019-04-27 23:52:44
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  567 non-null    float64
#  2   Urban     1496 non-null   float64
# dtypes: float64(3)
# memory usage: 68.0 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
resample_df = loc_pivot_df.resample('W').sum()
resample_df
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94
# 2019-02-10  115.80    974.34  2162.64
# 2019-02-17   95.82   1045.50  2235.07
# 2019-02-24  419.06   1412.74  2466.29
# 2019-03-03  175.14    858.46  2218.20
# 2019-03-10  303.94    925.27  2470.93
# 2019-03-17  163.39    906.20  2044.42
# 2019-03-24  189.76   1122.20  2368.37
# 2019-03-31  199.42   1045.06  1942.77
# 2019-04-07  501.24   1010.73  2356.70
# 2019-04-14  269.79    784.82  2390.72
# 2019-04-21  214.14   1149.27  2303.80
# 2019-04-28  191.85   1169.04  1909.51

# %%
# 9. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 

# Import the style from Matplotlib.
from matplotlib import style
# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# %%
fare_vs_citytype = resample_df.plot(figsize=(20,6))
fare_vs_citytype.set_title('Total Fare by City Type')
fare_vs_citytype.set_ylabel('Fare in US$')
plt.show()
plt.savefig('Analysis/PyBer_fare_summary.png')
